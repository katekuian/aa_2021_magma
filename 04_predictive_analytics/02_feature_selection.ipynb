# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso

# %%
trips_hourly_df = pd.read_pickle("../00_data/trips_hourly_engineered.pkl")
trips_hourly_df.columns
# Out:
# Index(['starting_trips', 'ongoing_trips_prev', 'in_service_bikes_rolling',
#        'available_bikes', 'max_temp', 'min_temp', 'precip', 'hour',
#        'day_of_week', 'month', 'day_of_year', 'week', 'is_weekday',
#        'is_holiday'],
#       dtype='object')

# %%
trips_hourly_df.corr()
# Out:
#                           starting_trips  ongoing_trips_prev  \
# starting_trips                  1.000000            0.568770
# ongoing_trips_prev              0.568770            1.000000
# in_service_bikes_rolling        0.150725            0.108004
# available_bikes                 0.132862            0.076131
# max_temp                        0.045441            0.045124
# min_temp                        0.042555            0.044232
# precip                         -0.066599           -0.053256
# hour                            0.390721            0.267799
# day_of_week                    -0.125066            0.077412
# month                           0.130403            0.008203
# day_of_year                     0.131367            0.007004
# week                            0.132594            0.007268
# is_weekday                      0.173193           -0.067919
# is_holiday                     -0.064962           -0.023646
#
#                           in_service_bikes_rolling  available_bikes  max_temp  \
# starting_trips                            0.150725         0.132862  0.045441
# ongoing_trips_prev                        0.108004         0.076131  0.045124
# in_service_bikes_rolling                  1.000000         0.999488  0.588799
# available_bikes                           0.999488         1.000000  0.589092
# max_temp                                  0.588799         0.589092  1.000000
# min_temp                                  0.587540         0.587857  0.999187
# precip                                   -0.120945        -0.119589 -0.159825
# hour                                     -0.010833        -0.019486  0.174904
# day_of_week                               0.002583         0.000098  0.018038
# month                                     0.363219         0.364032  0.402630
# day_of_year                               0.360245         0.361087  0.402897
# week                                      0.380523         0.381417  0.413392
# is_weekday                               -0.001500         0.000682 -0.028779
# is_holiday                               -0.062543        -0.061968 -0.050052
#
#                           min_temp    precip      hour  day_of_week     month  \
# starting_trips            0.042555 -0.066599  0.390721    -0.125066  0.130403
# ongoing_trips_prev        0.044232 -0.053256  0.267799     0.077412  0.008203
# in_service_bikes_rolling  0.587540 -0.120945 -0.010833     0.002583  0.363219
# available_bikes           0.587857 -0.119589 -0.019486     0.000098  0.364032
# max_temp                  0.999187 -0.159825  0.174904     0.018038  0.402630
# min_temp                  1.000000 -0.164073  0.172621     0.020035  0.402623
# precip                   -0.164073  1.000000  0.033648    -0.011873 -0.106644
# hour                      0.172621  0.033648  1.000000    -0.001160 -0.009615
# day_of_week               0.020035 -0.011873 -0.001160     1.000000 -0.001312
# month                     0.402623 -0.106644 -0.009615    -0.001312  1.000000
# day_of_year               0.402973 -0.109076 -0.009668    -0.000959  0.996479
# week                      0.413222 -0.105436 -0.009321     0.004062  0.965992
# is_weekday               -0.031591  0.008250 -0.000056    -0.790160 -0.007277
# is_holiday               -0.049782  0.079465  0.005331    -0.080557  0.014837
#
#                           day_of_year      week  is_weekday  is_holiday
# starting_trips               0.131367  0.132594    0.173193   -0.064962
# ongoing_trips_prev           0.007004  0.007268   -0.067919   -0.023646
# in_service_bikes_rolling     0.360245  0.380523   -0.001500   -0.062543
# available_bikes              0.361087  0.381417    0.000682   -0.061968
# max_temp                     0.402897  0.413392   -0.028779   -0.050052
# min_temp                     0.402973  0.413222   -0.031591   -0.049782
# precip                      -0.109076 -0.105436    0.008250    0.079465
# hour                        -0.009668 -0.009321   -0.000056    0.005331
# day_of_week                 -0.000959  0.004062   -0.790160   -0.080557
# month                        0.996479  0.965992   -0.007277    0.014837
# day_of_year                  1.000000  0.966868   -0.007621    0.015020
# week                         0.966868  1.000000   -0.004778   -0.022763
# is_weekday                  -0.007621 -0.004778    1.000000    0.015476
# is_holiday                   0.015020 -0.022763    0.015476    1.000000

# %%
for id_1, variable in enumerate(trips_hourly_df.columns):
    for id_2, comp_variable in enumerate(trips_hourly_df.columns):
        if id_1 < id_2:
            corrcoeff = np.corrcoef(
                [
                    trips_hourly_df[variable].astype("float64"),
                    trips_hourly_df[comp_variable].astype("float64"),
                ]
            )[0][1]
            if corrcoeff > 0.7:
                print(variable, comp_variable, corrcoeff)
# Out:
# in_service_bikes_rolling available_bikes 0.9994877210528004
# max_temp min_temp 0.9991874178519857
# month day_of_year 0.9964794091054356
# month week 0.9659922422048107
# day_of_year week 0.9668681338578687

# %%
trips_hourly_df = trips_hourly_df.drop(
    columns=["in_service_bikes_rolling", "max_temp", "day_of_year", "week"]
)
trips_hourly_df.head(2)
# Out:
#                      starting_trips  ongoing_trips_prev  available_bikes  \
# index
# 2019-01-01 01:00:00             8.0                 2.0            871.0
# 2019-01-01 02:00:00            11.0                 4.0            869.0
#
#                      min_temp  precip  hour  day_of_week  month  is_weekday  \
# index
# 2019-01-01 01:00:00      15.6     0.0     1            1      1        True
# 2019-01-01 02:00:00      15.0     0.0     2            1      1        True
#
#                      is_holiday
# index
# 2019-01-01 01:00:00        True
# 2019-01-01 02:00:00        True

# %%
input_features = trips_hourly_df.reset_index().drop(columns=["starting_trips", "index"])
predicted_varible = trips_hourly_df["starting_trips"]

# %%
scaler = StandardScaler()
input_features_scaled = scaler.fit_transform(input_features.values)

# %%
model = Lasso(alpha=1)
model.fit(input_features_scaled, predicted_varible)
print("Coefficients ", model.coef_)
# Out:
# Coefficients  [ 9.97596999  0.7510709  -0.35298015 -0.          4.71250765 -0.
#   1.62708272  3.35667478 -0.21490481]

# %% [markdown]
# The results of Lasso regression yield 0 coefficient for features precipitation, is_weekday and is_holiday. Therefore we will drop these for the predictive analytics section.

# %%
trips_hourly_df = trips_hourly_df.drop(columns={"precip", "day_of_week"})

# %%
trips_hourly_df.to_pickle("../00_data/trips_hourly_selected.pkl")
