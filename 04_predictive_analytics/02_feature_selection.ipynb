# %%
import pandas as pd
import numpy as np

# %%
trips_df = pd.read_pickle('../00_data/trips_hourly_engineered.pkl')

# %%
trips_df.columns
# Out:
# Index(['starting_trips', 'ongoing_trips_prev', 'in_service_bikes_rolling',
#        'available_bikes', 'max_temp', 'min_temp', 'precip', 'hour',
#        'day_of_week', 'month', 'day_of_year', 'week', 'is_weekday',
#        'is_holiday'],
#       dtype='object')

# %%
trips_df.corr()
# Out:
#                           starting_trips  ongoing_trips_prev  \
# starting_trips                  1.000000            0.568770
# ongoing_trips_prev              0.568770            1.000000
# in_service_bikes_rolling        0.150725            0.108004
# available_bikes                 0.132862            0.076131
# max_temp                        0.045441            0.045124
# min_temp                        0.042555            0.044232
# precip                         -0.066599           -0.053256
# hour                            0.390721            0.267799
# day_of_week                    -0.125066            0.077412
# month                           0.130403            0.008203
# day_of_year                     0.131367            0.007004
# week                            0.132594            0.007268
# is_weekday                      0.173193           -0.067919
# is_holiday                     -0.064962           -0.023646
#
# ...

# %%
for id_1, variable in enumerate(trips_df.columns):
    for id_2, comp_variable in enumerate(trips_df.columns):
        if id_1 < id_2 :
            corrcoeff = np.corrcoef([trips_df[variable].astype('float64'), trips_df[comp_variable].astype('float64')])[0][1]
            if corrcoeff > 0.7:
                print(variable, comp_variable, corrcoeff)
# Out:
# in_service_bikes_rolling available_bikes 0.9994877210528004
# max_temp min_temp 0.9991874178519857
# month day_of_year 0.9964794091054356
# month week 0.9659922422048107
# day_of_year week 0.9668681338578687

# %%
trips_df_reduced = trips_df.drop(columns=['in_service_bikes_rolling', 'max_temp', 'day_of_year', 'week'])
trips_df_reduced
# Out:
#                      starting_trips  ongoing_trips_prev  available_bikes  \
# index
# 2019-01-01 01:00:00             8.0                 2.0            871.0
# 2019-01-01 02:00:00            11.0                 4.0            869.0
# 2019-01-01 03:00:00             2.0                 3.0            870.0
# 2019-01-01 06:00:00             2.0                 1.0            872.0
# 2019-01-01 07:00:00             3.0                 1.0            872.0
# ...                             ...                 ...              ...
# 2019-12-31 19:00:00            28.0                12.0            894.0
# 2019-12-31 20:00:00            40.0                 8.0            897.0
# 2019-12-31 21:00:00            23.0                15.0            890.0
# 2019-12-31 22:00:00            16.0                 6.0            899.0
# 2019-12-31 23:00:00            12.0                 7.0            898.0
#
#                      min_temp  precip  hour  day_of_week  month  is_weekday  \
# ...

# %%
# input_features = [
#       'starting_trips', 'ongoing_trips_prev', 'in_service_bikes_rolling', 'available_bikes', # bicycle availability features
#       'max_temp', 'min_temp', 'precip', # weather features
#       'hour', 'day_of_week', 'month', 'day_of_year', 'week', 'is_weekday', # time features
#       'is_holiday' # holiday feature
# ]

# %%
trips_df.to_pickle('../00_data/trips_hourly_selected.pkl')
