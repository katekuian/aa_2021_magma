# %%
import requests
import pandas as pd
import h3

# %% [markdown]
# Explain what hexagons are
#
# First of all we wil create a DataFrame with all hexagons where a trip started or ended. This hexagons are of interest to us, as demand to or from this area may be influenced by the number and type of buildings and facilities.

# %%
trips_df = pd.read_pickle('../00_data/trips.pkl')

# %%
def convert_to_hex(latitude, longitude, resolution):
    return h3.geo_to_h3(
        lat=latitude,
        lng=longitude,
        resolution=resolution
    )

# %%
resolution = 8

trips_df['start_hex'] = trips_df.apply(lambda trip: convert_to_hex(
    trip['start_latitude'], 
    trip['start_longitude'], 
    resolution
), axis=1)

trips_df['end_hex'] = trips_df.apply(lambda trip: convert_to_hex(
    trip['end_latitude'],
    trip['end_longitude'],
    resolution
), axis=1)

# %%
number_of_unique_hexagons = pd.concat([trips_df['start_hex'], trips_df['end_hex']]).unique().size
print(
    f"We have identified {number_of_unique_hexagons} for h3 hexagons with resolution {resolution}."
)
# Out:
# We have identified 75 for h3 hexagons with resolution 8.

# %%
# create a dataframe representing H3 hexagons in LA
# note: only hexagons are depicted where at least one trip started or ended
hexagons_df = pd.DataFrame()
hexagons_df['hex'] = pd.concat([trips_df['start_hex'], trips_df['end_hex']]).unique()
hexagons_df.head(2)
# Out:
#                hex
# 0  8829a1d757fffff
# 1  8829a1d755fffff

# %% [markdown]
# In the next step we will retrieve information about all hexagons in LA, Santa Monica and Burbank. We will query the Openstreetmap (OSM) API. OSM is a free of charge tool. Can be practiced with turbo : link.
# ................................

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

# %%
overpass_query = """
  [out:json]; 
  area[name = "Los Angeles"]->.a;
	area[name = "Santa Monica"]->.b; 
	area[name = "Burbank"]->.c; 
    (   
      node(area.a)[amenity=bar];
      node(area.a)[amenity=restaurant]; 
      node(area.a)[amenity=pub];
      node(area.a)[amenity=ice_cream];
      node(area.a)[amenity=food_court];
      node(area.a)[amenity=fast_food];
      node(area.a)[amenity=biergarten];
      node(area.a)[amenity=cafe];
      
      node(area.b)[amenity=bar];
      node(area.b)[amenity=restaurant]; 
      node(area.b)[amenity=pub];
      node(area.b)[amenity=ice_cream];
      node(area.b)[amenity=food_court];
      node(area.b)[amenity=fast_food];
      node(area.b)[amenity=biergarten];
      node(area.b)[amenity=cafe];

      node(area.c)[amenity=bar];
      node(area.c)[amenity=restaurant]; 
      node(area.c)[amenity=pub];
      node(area.c)[amenity=ice_cream];
      node(area.c)[amenity=food_court];
      node(area.c)[amenity=fast_food];
      node(area.c)[amenity=biergarten];
      node(area.c)[amenity=cafe];
      
    ); 
    out;  
"""
response = requests.get(overpass_url, params={"data": overpass_query})
sustenance_data = response.json()

# %%
sustenance_data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.57 93a4d346',
#  'osm3s': {'timestamp_osm_base': '2021-12-11T15:36:44Z',
#   'timestamp_areas_base': '2021-12-11T15:13:26Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 72448982,
#    'lat': 34.0762169,
#    'lon': -118.2160197,
#    'tags': {'amenity': 'fast_food',
#     'cuisine': 'japanese',
#     'drive_through': 'yes',
#     'name': 'Yoshinoya',
#     'source': 'usgs_imagery;survey;image',
#     'source_ref': 'AM909_DSCV1655'}},
#   {'type': 'node',
#    'id': 72448995,
#    'lat': 34.0766932,
#    'lon': -118.2160126,
#    'tags': {'amenity': 'fast_food',
#     'cuisine': 'burger',
#     'drive_through': 'yes',
#     'name': 'Jack in the Box',
#     'source': 'usgs_imagery;survey;image',
#     'source_ref': 'AM909_DSCV1656'}},
#   {'type': 'node',
#    'id': 77741928,
#    'lat': 34.190943,
#    'lon': -118.3305106,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'american',
#     'name': 'Hometown Buffet'}},
#   {'type': 'node',
#    'id': 344723703,
#    'lat': 34.1855717,
#    'lon': -118.3164955,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Baja Fresh',
#     'brand:wikidata': 'Q2880019',
#     'brand:wikipedia': 'en:Baja Fresh',
#     'cuisine': 'mexican',
#     'name': 'Baja Fresh',
#     'source': 'yahoo_imagery',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 344723888,
#    'lat': 34.1856243,
#    'lon': -118.3163295,
#    'tags': {'amenity': 'fast_food',
#     'brand': "Jersey Mike's Subs",
#     'brand:wikidata': 'Q6184897',
#     'brand:wikipedia': "en:Jersey Mike's Subs",
#     'cuisine': 'sandwich',
#     'name': "Jersey Mike's Subs",
#     'short_name': "Jersey Mike's",
#     'source': 'yahoo_imagery',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 344727689,
#    'lat': 34.1882058,
#    'lon': -118.3191305,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Taco Bell',
#     'brand:wikidata': 'Q752941',
#     'brand:wikipedia': 'en:Taco Bell',
#     'cuisine': 'tex-mex',
#     'name': 'Taco Bell',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 344727935,
#    'lat': 34.1894766,
#    'lon': -118.3197656,
#    'tags': {'amenity': 'restaurant',
#     'brand': 'Pizza Hut',
#     'brand:wikidata': 'Q191615',
#     'brand:wikipedia': 'en:Pizza Hut',
#     'cuisine': 'pizza',
#     'name': 'Pizza Hut'}},
#   {'type': 'node',
#    'id': 346300785,
#    'lat': 34.2594656,
#    'lon': -118.3028134,
#    'tags': {'amenity': 'pub', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 349338599,
#    'lat': 34.0996138,
#    'lon': -118.3289013,
#    'tags': {'amenity': 'restaurant',
#     'created_by': 'Potlatch 0.10f',
#     'name': "Big Wang's"}},
#   {'type': 'node',
#    'id': 349338821,
#    'lat': 34.0998981,
#    'lon': -118.3293304,
#    'tags': {'addr:housenumber': '6371',
#     'addr:street': 'Selma Avenue',
#     'amenity': 'restaurant',
#     'name': 'Cafe Etc.',
#     'opening_hours': 'Mo-Fr 7:00-21:00; Sa-Su 7:00-21:00',
#     'phone': '+1 323-464-8824',
#     'website': 'http://www.caffeetc.com/'}},
#   {'type': 'node',
#    'id': 349339405,
#    'lat': 34.0981853,
#    'lon': -118.3275366,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '6922',
#     'addr:postcode': '90028',
#     'addr:state': 'CA',
#     'addr:street': 'Sunset Boulevard',
#     'addr:suite': '106',
#     'amenity': 'fast_food',
#     'brand': 'Baja Fresh',
#     'brand:wikidata': 'Q2880019',
#     'brand:wikipedia': 'en:Baja Fresh',
#     'contact:phone': '+1-323-467-4620',
#     'contact:website': 'http://www.bajafresh.com/',
#     'cuisine': 'mexican',
#     'name': 'Baja Fresh',
#     'opening_hours': 'Mo-Th 10:00-22:00; Fr-Sa 10:00-23:00; Su 10:00-22:00',
#     'ref:store_number': '30266',
#     'source': 'http://www.bajafresh.com/stores/30266',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 349340479,
#    'lat': 34.0744214,
#    'lon': -118.3767739,
#    'tags': {'alt_name': 'Chipotle Mexican Grill',
#     'amenity': 'fast_food',
#     'brand': 'Chipotle',
#     'brand:wikidata': 'Q465751',
#     'brand:wikipedia': 'en:Chipotle Mexican Grill',
#     'contact:website': 'https://chipotle.com/',
#     'cuisine': 'mexican',
#     'name': 'Chipotle',
#     'official_name': 'Chipotle Mexican Grill',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 353942124,
#    'lat': 34.2599805,
#    'lon': -118.3152399,
#    'tags': {'amenity': 'cafe', 'name': 'Backdoor Bakery'}},
#   {'type': 'node',
#    'id': 353942568,
#    'lat': 34.2602353,
#    'lon': -118.3147464,
#    'tags': {'amenity': 'restaurant',
#     'brand': 'Pizza Hut',
#     'brand:wikidata': 'Q191615',
#     'brand:wikipedia': 'en:Pizza Hut',
#     'cuisine': 'pizza',
#     'name': 'Pizza Hut'}},
#   {'type': 'node',
#    'id': 354910320,
#    'lat': 34.2602359,
#    'lon': -118.3149028,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Subway',
#     'brand:wikidata': 'Q244457',
#     'brand:wikipedia': 'en:Subway (restaurant)',
#     'cuisine': 'sandwich',
#     'name': 'Subway',
#     'source': 'Yahoo',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 360256621,
#    'lat': 34.2601218,
#    'lon': -118.3239296,
#    'tags': {'amenity': 'restaurant', 'name': 'Giamelas'}},
#   {'type': 'node',
#    'id': 360258239,
#    'lat': 34.2600527,
#    'lon': -118.3233849,
#    'tags': {'amenity': 'ice_cream',
#     'brand': 'Baskin-Robbins',
#     'brand:wikidata': 'Q584601',
#     'brand:wikipedia': 'en:Baskin-Robbins',
#     'cuisine': 'ice_cream',
#     'name': 'Baskin-Robbins'}},
#   {'type': 'node',
#    'id': 360258364,
#    'lat': 34.2599959,
#    'lon': -118.3233849,
#    'tags': {'amenity': 'restaurant', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 368174024,
#    'lat': 34.0175106,
#    'lon': -118.4517456,
#    'tags': {'addr:state': 'CA',
#     'amenity': 'cafe',
#     'ele': '47',
#     'gnis:county_name': 'Los Angeles',
#     'gnis:feature_id': '1693161',
#     'gnis:import_uuid': '57871b70-0100-4405-bb30-88b2e001a944',
#     'gnis:reviewed': 'no'}},
#   {'type': 'node',
#    'id': 408540804,
#    'lat': 34.0619072,
#    'lon': -118.3096159,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'korean',
#     'name': 'Tofu Village',
#     'name:ko': '두부 마을'}},
#   {'type': 'node',
#    'id': 416766635,
#    'lat': 33.9871321,
#    'lon': -118.4734125,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'american',
#     'name': "Danny's Bistro and Cafe"}},
#   {'type': 'node',
#    'id': 437768821,
#    'lat': 34.0339677,
#    'lon': -118.4927478,
#    'tags': {'amenity': 'fast_food',
#     'cuisine': 'ice_cream',
#     'name': 'Pinkberry'}},
#   {'type': 'node',
#    'id': 437773582,
#    'lat': 34.029328,
#    'lon': -118.4984834,
#    'tags': {'addr:city': 'Santa Monica',
#     'addr:housenumber': '1018',
#     'addr:postcode': '90403',
#     'addr:state': 'CA',
#     'addr:street': 'Montana Avenue',
#     'amenity': 'pub',
#     'name': "Father's Office",
#     'phone': '+1-310-736-2224',
#     'website': 'https://fathersoffice.com/'}},
#   {'type': 'node',
#    'id': 437850231,
#    'lat': 34.0307057,
#    'lon': -118.4836931,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'thai',
#     'name': 'Thai Dishes'}},
#   {'type': 'node',
#    'id': 439771131,
#    'lat': 34.0127365,
#    'lon': -118.4667404,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'burger',
#     'name': 'Shaka Shack'}},
#   {'type': 'node',
#    'id': 439817143,
#    'lat': 34.0286219,
#    'lon': -118.4862943,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 439826035,
#    'lat': 34.0309265,
#    'lon': -118.4775052,
#    'tags': {'amenity': 'restaurant', 'name': 'Santa Monica Bistro'}},
#   {'type': 'node',
#    'id': 439931638,
#    'lat': 34.0341961,
#    'lon': -118.4924929,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'american',
#     'name': '17th Street Cafe'}},
#   {'type': 'node',
#    'id': 439931915,
#    'lat': 34.0335274,
#    'lon': -118.4932833,
#    'tags': {'addr:city': 'Santa Monica',
#     'addr:housenumber': '1534',
#     'addr:postcode': '90403',
#     'addr:state': 'CA',
#     'addr:street': 'Montana Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'american',
#     'name': "Margo's",
#     'phone': '+1-310-829-3990',
#     'website': 'https://www.margossantamonica.com/'}},
#   {'type': 'node',
#    'id': 439932222,
#    'lat': 34.0327921,
#    'lon': -118.4942262,
#    'tags': {'addr:housenumber': '1426',
#     'addr:postcode': '90402',
#     'addr:street': 'Montana Avenue',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'wifi': 'yes'}},
#   {'type': 'node',
#    'id': 439932447,
#    'lat': 34.0327139,
#    'lon': -118.4943378,
#    'tags': {'amenity': 'cafe', 'name': 'Via Dolce'}},
#   {'type': 'node',
#    'id': 439932752,
#    'lat': 34.0324506,
#    'lon': -118.4950672,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': "Pradeep's"}},
#   {'type': 'node',
#    'id': 439932943,
#    'lat': 34.0326285,
#    'lon': -118.4948527,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'american',
#     'name': 'Blue Plate'}},
#   {'type': 'node',
#    'id': 439935749,
#    'lat': 34.0256433,
#    'lon': -118.4905097,
#    'tags': {'addr:city': 'Santa Monica',
#     'addr:housenumber': '1213',
#     'addr:postcode': '90403',
#     'addr:state': 'CA',
#     'addr:street': 'Wilshire Boulevard',
#     'amenity': 'restaurant',
#     'capacity': '100',
#     'cuisine': 'american',
#     'name': "Ingo's Tasty Diner"}},
#   {'type': 'node',
#    'id': 439936037,
#    'lat': 34.0257104,
#    'lon': -118.4904465,
#    'tags': {'amenity': 'cafe', 'name': 'Vienna Bakery', 'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 439936297,
#    'lat': 34.0259136,
#    'lon': -118.4901836,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Subway',
#     'brand:wikidata': 'Q244457',
#     'brand:wikipedia': 'en:Subway (restaurant)',
#     'cuisine': 'sandwich',
#     'name': 'Subway',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 439949411,
#    'lat': 34.0290582,
#    'lon': -118.4986661,
#    'tags': {'addr:city': 'Santa Monica',
#     'addr:housenumber': '1002',
#     'addr:postcode': '90403',
#     'addr:state': 'CA',
#     'addr:street': 'Montana Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'american;seafood;salad',
#     'name': "Art's Table",
#     'phone': '+1-310-395-2500',
#     'website': 'https://www.artstablesm.com/'}},
#   {'type': 'node',
#    'id': 439949561,
#    'lat': 34.0292668,
#    'lon': -118.4985782,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': "Louise's Trattoria"}},
#   {'type': 'node',
#    'id': 439949564,
#    'lat': 34.0291387,
#    'lon': -118.4991961,
#    'tags': {'amenity': 'restaurant', 'name': 'Rosti'}},
#   {'type': 'node',
#    'id': 439949674,
#    'lat': 34.0276281,
#    'lon': -118.5005852,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Panda Express and Pioneer Boulangerie'}},
#   {'type': 'node',
#    'id': 439949776,
#    'lat': 34.0270545,
#    'lon': -118.5017882,
#    'tags': {'amenity': 'cafe', 'name': 'Starbucks'}},
#   {'type': 'node',
#    'id': 439949779,
#    'lat': 34.0272463,
#    'lon': -118.501065,
#    'tags': {'amenity': 'cafe', 'name': 'Marmalade'}},
#   {'type': 'node',
#    'id': 440621215,
#    'lat': 34.1017216,
#    'lon': -118.3373325,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 441941600,
#    'lat': 34.0226655,
#    'lon': -118.4006804,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'thai',
#     'name': 'Natalee Thai'}},
#   {'type': 'node',
#    'id': 455670372,
#    'lat': 34.0831841,
#    'lon': -118.3262786,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'peruvian',
#     'name': "Mario's Peruvian Restaurant"}},
#   {'type': 'node',
#    'id': 457696639,
#    'lat': 34.1560719,
#    'lon': -118.3351721,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'peruvian',
#     'name': 'Coza Mama'}},
#   {'type': 'node',
#    'id': 464745074,
#    'lat': 34.0645693,
#    'lon': -118.2181096,
#    'tags': {'amenity': 'cafe', 'name': "Barbara's"}},
#   {'type': 'node',
#    'id': 464745080,
#    'lat': 34.0662117,
#    'lon': -118.2192511,
#    'tags': {'amenity': 'restaurant'}},
#   {'type': 'node',
#    'id': 470868182,
#    'lat': 34.0484694,
#    'lon': -118.2557823,
#    'tags': {'amenity': 'pub', 'name': "Casey's Irish"}},
#   {'type': 'node',
#    'id': 470872073,
#    'lat': 34.0596738,
#    'lon': -118.2369413,
#    'tags': {'addr:housenumber': '1001',
#     'addr:street': 'North Alameda Street',
#     'amenity': 'restaurant',
#     'contact:email': 'customerservice@philippes.com',
#     'contact:phone': '+1 (213) 628-3781',
#     'cuisine': 'american',
#     'name': 'Philippe The Original',
#     'name:en': 'Philippe The Original',
#     'opening_hours': 'Mo-Su 06:00-22:00',
#     'website': 'https://www.philippes.com/',
#     'wikidata': 'Q3309185'}},
#   {'type': 'node',
#    'id': 470881976,
#    'lat': 34.0448335,
#    'lon': -118.2495584,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '118',
#     'addr:state': 'CA',
#     'addr:street': 'East 6th Street',
#     'alt_name': "Cole's;Cole's Pacific Electric Buffet",
#     'amenity': 'restaurant',
#     'historic': 'restaurant',
#     'name': "Cole's P.E. Buffet",
#     'website': 'www.colesfrenchdip.com',
#     'wheelchair': 'no',
#     'wikipedia': "en:Cole's Pacific Electric Buffet"}},
#   {'type': 'node',
#    'id': 470881995,
#    'lat': 34.047039,
#    'lon': -118.2565671,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Bottega Louie',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 470888480,
#    'lat': 34.0509972,
#    'lon': -118.2447419,
#    'tags': {'amenity': 'restaurant', 'name': 'The Mighty'}},
#   {'type': 'node',
#    'id': 470888534,
#    'lat': 34.0511299,
#    'lon': -118.2448967,
#    'tags': {'amenity': 'restaurant', 'name': 'Lili Ya'}},
#   {'type': 'node',
#    'id': 470888603,
#    'lat': 34.0510825,
#    'lon': -118.2452603,
#    'tags': {'amenity': 'bar', 'name': 'The Edison', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 470889787,
#    'lat': 34.0499025,
#    'lon': -118.2399704,
#    'tags': {'addr:housenumber': '331',
#     'addr:postcode': '90012',
#     'addr:street': 'E. 1st St.',
#     'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'name': 'Restaurant Aoi'}},
#   {'type': 'node',
#    'id': 470890156,
#    'lat': 34.0499714,
#    'lon': -118.2400831,
#    'tags': {'addr:country': 'US',
#     'addr:housenumber': '327',
#     'addr:street': 'E 1st St.',
#     'amenity': 'restaurant',
#     'cuisine': 'japanese',
#     'name': 'Daikokuya'}},
#   {'type': 'node',
#    'id': 470891322,
#    'lat': 34.0449001,
#    'lon': -118.253359,
#    'tags': {'amenity': 'fast_food',
#     'branch': '®',
#     'brand': "Carl's Jr.",
#     'brand:wikidata': 'Q1043486',
#     'brand:wikipedia': "en:Carl's Jr.",
#     'cuisine': 'burger',
#     'name': "Carl's Jr.",
#     'takeaway': 'yes',
#     'website': 'https://www.carlsjr.com/'}},
#   {'type': 'node',
#    'id': 470893427,
#    'lat': 34.0517217,
#    'lon': -118.2666829,
#    'tags': {'amenity': 'restaurant', 'name': 'Great Thai'}},
#   {'type': 'node',
#    'id': 470895187,
#    'lat': 34.0448419,
#    'lon': -118.2644312,
#    'tags': {'amenity': 'restaurant',
#     'name': "Flanigan's",
#     'opening_hours': 'Mo-Fr 11:30-14:30, Su-Th 17:00-22:00, Fr,Sa 17:00-23:00',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 470895665,
#    'lat': 34.0449843,
#    'lon': -118.265798,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '800',
#     'addr:postcode': '90015',
#     'addr:state': 'CA',
#     'addr:street': 'West Olympic Boulevard',
#     'alcohol': 'yes',
#     'amenity': 'restaurant',
#     'brand': 'Yard House',
#     'brand:wikidata': 'Q21189156',
#     'brand:wikipedia': 'en:Yard House',
#     'cuisine': 'american',
#     'name': 'Yard House',
#     'opening_hours': 'Su-Th 11:00-24:00, Fr,Sa 11:00-01:00',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 470897843,
#    'lat': 34.0451265,
#    'lon': -118.2654812,
#    'tags': {'amenity': 'restaurant', 'name': "Trader Vic's"}},
#   {'type': 'node',
#    'id': 470897859,
#    'lat': 34.0445895,
#    'lon': -118.2651154,
#    'tags': {'amenity': 'restaurant', 'name': 'Rock N Fish'}},
#   {'type': 'node',
#    'id': 470897912,
#    'lat': 34.0406343,
#    'lon': -118.2696008,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 470897948,
#    'lat': 34.0440313,
#    'lon': -118.2652323,
#    'tags': {'amenity': 'restaurant', 'name': 'ESPN Zone'}},
#   {'type': 'node',
#    'id': 470900133,
#    'lat': 34.0488832,
#    'lon': -118.260969,
#    'tags': {'amenity': 'food_court',
#     'name': '7th&Fig Food Court',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 470920609,
#    'lat': 34.0477282,
#    'lon': -118.258819,
#    'tags': {'amenity': 'restaurant',
#     'name': 'The Bloc Food Court',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 471249994,
#    'lat': 34.0506093,
#    'lon': -118.2481571,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '308',
#     'addr:postcode': '90013',
#     'addr:state': 'CA',
#     'addr:street': 'South Broadway',
#     'amenity': 'fast_food',
#     'brand': 'Subway',
#     'brand:wikidata': 'Q244457',
#     'brand:wikipedia': 'en:Subway (restaurant)',
#     'contact:fax': '+1-213-626-1845',
#     'contact:phone': '+1-213-626-1605',
#     'contact:website': 'http://www.subway.com/',
#     'cuisine': 'sandwich',
#     'name': 'Subway',
#     'opening_hours': 'Mo-Fr 06:00-22:00; Sa-Su 07:00-21:00',
#     'ref:store_number': '26656',
#     'source': 'http://local.subway.com/FWPCons/frmSiteMainPage.aspx?CC=USA&LC=ENG&SS=26656-0',
#     'takeaway': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 471249997,
#    'lat': 34.0479704,
#    'lon': -118.2471827,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '400',
#     'addr:postcode': '90013',
#     'addr:state': 'CA',
#     'addr:street': 'S Main Street',
#     'amenity': 'restaurant',
#     'cuisine': 'american',
#     'name': 'Ledlow',
#     'opening_hours': 'Su-Th 08:00-15:00,17:30-23:00;Fr-Sa 08:00-15:00,17:30-24:00',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 471250006,
#    'lat': 34.050139,
#    'lon': -118.2485277,
#    'tags': {'amenity': 'fast_food',
#     'brand': "McDonald's",
#     'brand:wikidata': 'Q38076',
#     'brand:wikipedia': "en:McDonald's",
#     'cuisine': 'burger',
#     'name': "McDonald's",
#     'takeaway': 'yes',
#     'website': 'http://www.mcdonalds.com/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 471255269,
#    'lat': 34.051302,
#    'lon': -118.2570963,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Drago Centro',
#     'name:zh': 'Drago Ristorante意大利餐厅'}},
#   {'type': 'node',
#    'id': 471255273,
#    'lat': 34.0481231,
#    'lon': -118.261834,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Corner Bakery',
#     'brand:wikidata': 'Q5171598',
#     'brand:wikipedia': 'en:Corner Bakery Cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Corner Bakery',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 471255278,
#    'lat': 34.0525962,
#    'lon': -118.2571993,
#    'tags': {'amenity': 'restaurant', 'name': 'Ciudad'}},
#   {'type': 'node',
#    'id': 471255285,
#    'lat': 34.0486992,
#    'lon': -118.2589503,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Wokcano',
#     'website': 'https://www.wokcanorestaurant.com/'}},
#   {'type': 'node',
#    'id': 471255286,
#    'lat': 34.0492588,
#    'lon': -118.2563746,
#    'tags': {'amenity': 'restaurant', 'name': 'Wolfgang Puck'}},
#   {'type': 'node',
#    'id': 471255287,
#    'lat': 34.0490405,
#    'lon': -118.2560063,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Subway',
#     'brand:wikidata': 'Q244457',
#     'brand:wikipedia': 'en:Subway (restaurant)',
#     'cuisine': 'sandwich',
#     'name': 'Subway',
#     'operator': 'Subway',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 471255289,
#    'lat': 34.0491116,
#    'lon': -118.2564869,
#    'tags': {'amenity': 'bar', 'name': 'Library Bar'}},
#   {'type': 'node',
#    'id': 471255290,
#    'lat': 34.0511811,
#    'lon': -118.2558175,
#    'tags': {'amenity': 'restaurant', 'name': 'Cafe Pinot'}},
#   {'type': 'node',
#    'id': 471255295,
#    'lat': 34.049965,
#    'lon': -118.2573452,
#    'tags': {'addr:housename': 'Pegasus Building',
#     'amenity': 'restaurant',
#     'cuisine': 'american',
#     'name': 'Daily Grill'}},
#   {'type': 'node',
#    'id': 471255296,
#    'lat': 34.0485569,
#    'lon': -118.258255,
#    'tags': {'addr:street': 'West 7th Street',
#     'amenity': 'restaurant',
#     'brand': 'The Counter',
#     'brand:wikidata': 'Q7727763',
#     'brand:wikipedia': 'en:The Counter',
#     'cuisine': 'burger',
#     'name': 'The Counter'}},
#   {'type': 'node',
#    'id': 471255297,
#    'lat': 34.0486352,
#    'lon': -118.2583666,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 491731234,
#    'lat': 34.1181925,
#    'lon': -118.1898646,
#    'tags': {'amenity': 'restaurant', 'name': "Juanita's"}},
#   {'type': 'node',
#    'id': 506537817,
#    'lat': 33.9853271,
#    'lon': -118.425096,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '12740',
#     'addr:street': 'Culver Boulevard',
#     'amenity': 'restaurant',
#     'name': "Ronnies's Diner"}},
#   {'type': 'node',
#    'id': 517053662,
#    'lat': 34.2084819,
#    'lon': -118.3407039,
#    'tags': {'amenity': 'fast_food', 'name': "Woody's"}},
#   {'type': 'node',
#    'id': 518251994,
#    'lat': 34.1557696,
#    'lon': -118.3461499,
#    'tags': {'amenity': 'fast_food', 'name': "Togo's"}},
#   {'type': 'node',
#    'id': 518251995,
#    'lat': 34.1556488,
#    'lon': -118.346991,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 527473763,
#    'lat': 34.0184296,
#    'lon': -118.498926,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'note': 'Onside Barnes & Noble',
#     'official_name': 'Starbucks Coffee',
#     'operator': 'Starbucks Coffee',
#     'takeaway': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 529213054,
#    'lat': 34.0463719,
#    'lon': -118.2628977,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'american',
#     'name': 'Original Pantry Cafe',
#     'opening_hours': '24/7',
#     'outdoor_seating': 'no',
#     'takeaway': 'yes',
#     'wheelchair': 'yes',
#     'wikidata': 'Q7102558'}},
#   {'type': 'node',
#    'id': 537891836,
#    'lat': 34.0284357,
#    'lon': -118.479966,
#    'tags': {'amenity': 'restaurant',
#     'brand': 'IHOP',
#     'brand:wikidata': 'Q1185675',
#     'brand:wikipedia': 'en:IHOP',
#     'cuisine': 'breakfast;pancake',
#     'name': 'IHOP',
#     'operator': 'International House of Pancakes'}},
#   {'type': 'node',
#    'id': 537891856,
#    'lat': 34.0313726,
#    'lon': -118.4828776,
#    'tags': {'addr:city': 'Santa Monica',
#     'addr:housenumber': '2002',
#     'addr:postcode': '90403',
#     'addr:state': 'CA',
#     'addr:street': 'Wilshire Boulevard',
#     'amenity': 'restaurant',
#     'brand': 'Fuddruckers',
#     'brand:wikidata': 'Q5507056',
#     'brand:wikipedia': 'en:Fuddruckers',
#     'capacity': '80',
#     'cuisine': 'burger',
#     'name': 'Fuddruckers',
#     'opening_hours': 'Mo-Th 11:00-21:00; Fr-Sa 11:00-22:00; Su 11:00-21:00',
#     'operator': 'Koo Koo Roo',
#     'takeaway': 'yes',
#     'website': 'https://www.fuddruckers.com/'}},
#   {'type': 'node',
#    'id': 537893661,
#    'lat': 34.0302467,
#    'lon': -118.4839609,
#    'tags': {'amenity': 'restaurant', 'name': "Fromin's Deli"}},
#   {'type': 'node',
#    'id': 539830065,
#    'lat': 34.0360394,
#    'lon': -118.4777237,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'note': "Inside the Albertson's grocery store",
#     'official_name': 'Starbucks Coffee',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 547239376,
#    'lat': 34.0037145,
#    'lon': -118.4330282,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'mexican',
#     'name': 'Quiadaiyn'}},
#   {'type': 'node',
#    'id': 553094391,
#    'lat': 34.0484928,
#    'lon': -118.247952,
#    'tags': {'addr:country': 'US',
#     'amenity': 'restaurant',
#     'name': 'Rocket Pizza'}},
#   {'type': 'node',
#    'id': 557241369,
#    'lat': 34.0453657,
#    'lon': -118.2529074,
#    'tags': {'amenity': 'restaurant',
#     'email': 'info@cliftonscafeteria.com',
#     'name': "Clifton's Cafeteria",
#     'phone': '213.627.1673',
#     'website': 'http://www.cliftonscafeteria.com/',
#     'wikidata': 'Q5133122',
#     'wikipedia': "en:Clifton's Cafeteria"}},
#   {'type': 'node',
#    'id': 559195733,
#    'lat': 34.1849611,
#    'lon': -118.3388107,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'mexican',
#     'name': 'Los Chavos Tacos'}},
#   {'type': 'node',
#    'id': 559279241,
#    'lat': 34.0269269,
#    'lon': -118.4555641,
#    'tags': {'amenity': 'cafe', 'name': 'Unurban Cafe'}},
#   {'type': 'node',
#    'id': 560066659,
#    'lat': 34.0486256,
#    'lon': -118.2476319,
#    'tags': {'addr:country': 'US',
#     'amenity': 'bar',
#     'name': 'Bar 107',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 560958815,
#    'lat': 34.0960683,
#    'lon': -118.3264426,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:country': 'US',
#     'addr:full': '1360 Vine Street, Los Angeles, CA 90028',
#     'addr:housenumber': '1360',
#     'addr:postcode': '90028',
#     'addr:street': 'Vine Street',
#     'amenity': 'restaurant',
#     'cuisine': 'peruvian',
#     'name': 'Los Balcones'}},
#   {'type': 'node',
#    'id': 566336317,
#    'lat': 34.0474525,
#    'lon': -118.2257385,
#    'tags': {'amenity': 'restaurant',
#     'name': 'Purgatory Pizza',
#     'website': 'https://www.eatpurgatorypizza.com/'}},
#   {'type': 'node',
#    'id': 566383046,
#    'lat': 34.2592518,
#    'lon': -118.3063392,
#    'tags': {'amenity': 'fast_food',
#     'brand': "McDonald's",
#     'brand:wikidata': 'Q38076',
#     'brand:wikipedia': "en:McDonald's",
#     'cuisine': 'burger',
#     'name': "McDonald's",
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 566388310,
#    'lat': 34.2599921,
#    'lon': -118.3160267,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Jack in the Box',
#     'brand:wikidata': 'Q1538507',
#     'brand:wikipedia': 'en:Jack in the Box',
#     'cuisine': 'burger',
#     'name': 'Jack in the Box',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 566762873,
#    'lat': 34.0705686,
#    'lon': -118.4433778,
#    'tags': {'amenity': 'cafe', 'name': 'Kerckhoff Coffee House'}},
#   {'type': 'node',
#    'id': 594171613,
#    'lat': 34.121259,
#    'lon': -118.206804,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '5000',
#     'addr:postcode': '90042',
#     'addr:street': 'York Boulevard',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Café de Leche',
#     'phone': '+1 323 551-6828',
#     'website': 'https://www.cafedeleche.net/'}},
#   {'type': 'node',
#    'id': 595747755,
#    'lat': 34.1578394,
#    'lon': -118.4132217,
#    'tags': {'addr:city': 'Studio City',
#     'addr:country': 'US',
#     'addr:housenumber': '12851',
#     'addr:postcode': '91607',
#     'addr:state': 'CA',
#     'addr:street': 'Riverside Dr',
#     'amenity': 'cafe',
#     'gluten_free': 'yes',
#     'name': "Hugo's",
#     'source': 'survey;yahoo_imagery',
#     'website': 'https://www.hugosrestaurant.com/'}},
#   {'type': 'node',
#    'id': 595842138,
#    'lat': 34.1144391,
#    'lon': -118.1806849,
#    'tags': {'alt_name': 'Kentucky Fried Chicken',
#     'amenity': 'fast_food',
#     'brand': 'KFC',
#     'brand:wikidata': 'Q524757',
#     'brand:wikipedia': 'en:KFC',
#     'cuisine': 'chicken',
#     'name': "Popeye's Louisiana Kitchen",
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 595842489,
#    'lat': 34.121147,
#    'lon': -118.204555,
#    'tags': {'addr:housenumber': '5101',
#     'addr:postcode': '90042',
#     'addr:street': 'York Boulevard',
#     'amenity': 'fast_food',
#     'cuisine': 'italian;american',
#     'name': 'Town Pizza'}},
#   {'type': 'node',
#    'id': 595869764,
#    'lat': 34.122321,
#    'lon': -118.212295,
#    'tags': {'amenity': 'fast_food', 'cuisine': 'burger', 'name': 'Troy'}},
#   {'type': 'node',
#    'id': 595871350,
#    'lat': 34.118533,
#    'lon': -118.190928,
#    'tags': {'amenity': 'fast_food', 'name': 'Pizza Hut'}},
#   {'type': 'node',
#    'id': 598756282,
#    'lat': 34.09835,
#    'lon': -118.155677,
#    'tags': {'amenity': 'restaurant', 'name': "Charlie's Trio"}},
#   {'type': 'node',
#    'id': 600501584,
#    'lat': 34.101763,
#    'lon': -118.3350264,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '6667',
#     'addr:street': 'Hollywood Boulevard',
#     'alt_name': 'Musso and Frank Grill',
#     'amenity': 'restaurant',
#     'bar': 'yes',
#     'cocktails': 'yes',
#     'cuisine': 'american;steakhouse;italian',
#     'drink:beer': 'yes',
#     'drink:liquor': 'yes',
#     'drink:wine': 'yes',
#     'name': 'Musso & Frank',
#     'opening_hours': 'Tu-Sa 11:00-23:00; Su 16:00-21:00',
#     'phone': '+1-323-467-7788',
#     'start_date': '1919',
#     'website': 'https://mussoandfrank.com',
#     'wikidata': 'Q6943139',
#     'wikipedia': 'en:Musso & Frank Grill'}},
#   {'type': 'node',
#    'id': 607902540,
#    'lat': 34.0430002,
#    'lon': -118.2160946,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Subway',
#     'brand:wikidata': 'Q244457',
#     'brand:wikipedia': 'en:Subway (restaurant)',
#     'cuisine': 'sandwich',
#     'name': 'Subway',
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCR0332',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 607992174,
#    'lat': 34.0511181,
#    'lon': -118.2475744,
#    'tags': {'amenity': 'fast_food',
#     'brand': "Carl's Jr.",
#     'brand:wikidata': 'Q1043486',
#     'brand:wikipedia': "en:Carl's Jr.",
#     'cuisine': 'burger',
#     'name': "Carl's Jr.",
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCR0364',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 607992175,
#    'lat': 34.0509146,
#    'lon': -118.247615,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Sbarro',
#     'brand:wikidata': 'Q2589409',
#     'brand:wikipedia': 'en:Sbarro',
#     'cuisine': 'pizza',
#     'name': 'Sbarro',
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCR0364',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 607992176,
#    'lat': 34.0509782,
#    'lon': -118.2477031,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'El Pollo Loco',
#     'brand:wikidata': 'Q2353849',
#     'brand:wikipedia': 'en:El Pollo Loco',
#     'cuisine': 'mexican',
#     'fax': '213-626-4572',
#     'name': 'El Pollo Loco',
#     'opening_hours': '10:00-23:00',
#     'phone': '213-626-7975',
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCR0364',
#     'takeaway': 'yes',
#     'website': 'https://www.elpolloloco.com/'}},
#   {'type': 'node',
#    'id': 609065090,
#    'lat': 34.0614649,
#    'lon': -118.3092892,
#    'tags': {'amenity': 'cafe',
#     'name': 'Coffee Bean & Tea Leaf',
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCR0460'}},
#   {'type': 'node',
#    'id': 609065118,
#    'lat': 34.0614545,
#    'lon': -118.306404,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCR0466',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 610178476,
#    'lat': 34.0630316,
#    'lon': -118.2722924,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '230',
#     'addr:postcode': '90057',
#     'addr:state': 'CA',
#     'addr:street': 'Alvarado Street',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'wlan',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'phone': '2134341379',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.com/'}},
#   {'type': 'node',
#    'id': 610178501,
#    'lat': 34.0698964,
#    'lon': -118.2679404,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'El Pollo Loco',
#     'brand:wikidata': 'Q2353849',
#     'brand:wikipedia': 'en:El Pollo Loco',
#     'cuisine': 'mexican',
#     'name': 'El Pollo Loco',
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCR0532',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 610178519,
#    'lat': 34.080601,
#    'lon': -118.2606361,
#    'tags': {'amenity': 'fast_food',
#     'brand': "McDonald's",
#     'brand:wikidata': 'Q38076',
#     'brand:wikipedia': "en:McDonald's",
#     'cuisine': 'burger',
#     'drive_through': 'yes',
#     'name': "McDonald's",
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCR0549',
#     'takeaway': 'yes',
#     'website': 'http://www.mcdonalds.com/'}},
#   {'type': 'node',
#    'id': 610180416,
#    'lat': 34.077536,
#    'lon': -118.2572057,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Little Caesars',
#     'brand:wikidata': 'Q1393809',
#     'brand:wikipedia': 'en:Little Caesars',
#     'cuisine': 'pizza',
#     'name': 'Little Caesars',
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCR0598',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 610186123,
#    'lat': 34.0647554,
#    'lon': -118.2491904,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Jack in the Box',
#     'brand:wikidata': 'Q1538507',
#     'brand:wikipedia': 'en:Jack in the Box',
#     'cuisine': 'burger',
#     'drive_through': 'yes',
#     'name': 'Jack in the Box',
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCR0614',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 614042918,
#    'lat': 34.0734572,
#    'lon': -118.2114083,
#    'tags': {'amenity': 'fast_food',
#     'cuisine': 'mexican',
#     'name': 'King Taco',
#     'opening_hours': 'Su-Sa',
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCR9632'}},
#   {'type': 'node',
#    'id': 614042924,
#    'lat': 34.0740599,
#    'lon': -118.2087196,
#    'tags': {'amenity': 'fast_food',
#     'atm': 'yes',
#     'brand': "McDonald's",
#     'brand:wikidata': 'Q38076',
#     'brand:wikipedia': "en:McDonald's",
#     'cuisine': 'burger',
#     'name': "McDonald's",
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCR9638',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 614956135,
#    'lat': 34.1020084,
#    'lon': -118.186436,
#    'tags': {'amenity': 'cafe', 'name': 'Cycleway Coffee'}},
#   {'type': 'node',
#    'id': 614990288,
#    'lat': 34.0212898,
#    'lon': -118.2824417,
#    'tags': {'amenity': 'cafe',
#     'name': 'Trojan Grounds (Starbucks)',
#     'opening_hours': 'Mo-Su 00:00-24:00'}},
#   {'type': 'node',
#    'id': 616429286,
#    'lat': 34.138928,
#    'lon': -118.213861,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'cafe',
#     'name': 'Swörk Coffee',
#     'outdoor_seating': 'no'}},
#   {'type': 'node',
#    'id': 616430258,
#    'lat': 34.139552,
#    'lon': -118.20447,
#    'tags': {'amenity': 'fast_food', 'name': "Tommy's"}},
#   {'type': 'node',
#    'id': 616923792,
#    'lat': 34.062426,
#    'lon': -118.235849,
#    'tags': {'amenity': 'cafe', 'name': 'Homegirl Cafe'}},
#   {'type': 'node',
#    'id': 623431546,
#    'lat': 34.0244137,
#    'lon': -118.4920773,
#    'tags': {'amenity': 'restaurant', 'name': 'El Cholo'}},
#   {'type': 'node',
#    'id': 627183562,
#    'lat': 34.0122044,
#    'lon': -118.494212,
#    'tags': {'addr:city': 'Santa Monica',
#     'amenity': 'fast_food',
#     'brand': "McDonald's",
#     'brand:wikidata': 'Q38076',
#     'brand:wikipedia': "en:McDonald's",
#     'cuisine': 'burger',
#     'name': "McDonald's",
#     'takeaway': 'yes',
#     'website': 'http://www.mcdonalds.com/'}},
#   {'type': 'node',
#    'id': 634032208,
#    'lat': 33.7820572,
#    'lon': -118.2980958,
#    'tags': {'amenity': 'fast_food',
#     'cuisine': 'sandwich',
#     'drive_through': 'no',
#     'name': 'Subway',
#     'source': 'survey;image;usgs_imagery',
#     'source_ref': 'AM909_DSCS3097'}},
#   {'type': 'node',
#    'id': 640768126,
#    'lat': 34.0197502,
#    'lon': -118.4801728,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'mexican',
#     'name': 'Tacos por Favor',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 643387761,
#    'lat': 34.1017987,
#    'lon': -118.3405192,
#    'tags': {'amenity': 'restaurant',
#     'brand': 'Hard Rock Cafe',
#     'brand:wikidata': 'Q918151',
#     'brand:wikipedia': 'en:Hard Rock Cafe',
#     'cuisine': 'american',
#     'name': 'Hard Rock Cafe',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 651154560,
#    'lat': 34.2482947,
#    'lon': -118.6063655,
#    'tags': {'amenity': 'restaurant', 'name': 'Hot Tomato!'}},
#   {'type': 'node',
#    'id': 664153976,
#    'lat': 34.1020949,
#    'lon': -118.3362729,
#    'tags': {'amenity': 'cafe', 'name': 'Cafe Audrey'}},
#   {'type': 'node',
#    'id': 672875638,
#    'lat': 34.0622772,
#    'lon': -118.4471445,
#    'tags': {'amenity': 'restaurant',
#     'brand': 'California Pizza Kitchen',
#     'brand:wikidata': 'Q15109854',
#     'brand:wikipedia': 'en:California Pizza Kitchen',
#     'cuisine': 'pizza',
#     'name': 'California Pizza Kitchen'}},
#   {'type': 'node',
#    'id': 672875645,
#    'lat': 34.0619255,
#    'lon': -118.4476983,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '1000',
#     'addr:postcode': '90024',
#     'addr:state': 'CA',
#     'addr:street': 'Gayley Avenue',
#     'amenity': 'bar',
#     'name': "Rocco's Tavern",
#     'old_name': "Maloney's",
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 672908896,
#    'lat': 34.0624873,
#    'lon': -118.4473927,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'takeaway': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 679520105,
#    'lat': 34.1017294,
#    'lon': -118.3382697,
#    'tags': {'amenity': 'cafe', 'name': 'Snow White Cafe'}},
#   {'type': 'node',
#    'id': 683080610,
#    'lat': 34.0655825,
#    'lon': -118.2364274,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'chinese',
#     'description': 'Dim Sum',
#     'name': 'Golden Dragon Restaurant'}},
#   {'type': 'node',
#    'id': 683080613,
#    'lat': 34.0666824,
#    'lon': -118.2372669,
#    'tags': {'amenity': 'restaurant', 'name': 'Empress Pavilion'}},
#   {'type': 'node',
#    'id': 688280156,
#    'lat': 34.0291121,
#    'lon': -118.4863511,
#    'tags': {'amenity': 'restaurant', 'name': 'Bagel Nosh'}},
#   {'type': 'node',
#    'id': 688283954,
#    'lat': 34.0275785,
#    'lon': -118.488142,
#    'tags': {'amenity': 'restaurant', 'name': "Izzy's Deli"}},
#   {'type': 'node',
#    'id': 693968270,
#    'lat': 34.1274023,
#    'lon': -118.2122839,
#    'tags': {'amenity': 'cafe', 'name': 'The Green Bean'}},
#   {'type': 'node',
#    'id': 732641023,
#    'lat': 34.0169985,
#    'lon': -118.2822768,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Chipotle',
#     'brand:wikidata': 'Q465751',
#     'brand:wikipedia': 'en:Chipotle Mexican Grill',
#     'cuisine': 'mexican',
#     'name': 'Chipotle',
#     'official_name': 'Chipotle Mexican Grill',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 732741444,
#    'lat': 34.0624774,
#    'lon': -118.345318,
#    'tags': {'addr:housenumber': '5353',
#     'addr:street': 'Wilshire Boulevard',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'phone': '3239392071',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 806649044,
#    'lat': 34.0941377,
#    'lon': -118.2084689,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Jack in the Box',
#     'brand:wikidata': 'Q1538507',
#     'brand:wikipedia': 'en:Jack in the Box',
#     'cuisine': 'burger',
#     'drive_through': 'yes',
#     'name': 'Jack in the Box',
#     'source': 'usgs_imagery;survey;image',
#     'source_ref': 'AM909_DSCV1632',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 821384821,
#    'lat': 34.0302951,
#    'lon': -118.4615121,
#    'tags': {'addr:city': 'Santa Monica',
#     'amenity': 'restaurant',
#     'cuisine': 'regional',
#     'name': "Stefan's at LA Farm",
#     'phone': '310 449 4000',
#     'url': 'http://stefansatlafarm.com/'}},
#   {'type': 'node',
#    'id': 824230702,
#    'lat': 34.137166,
#    'lon': -118.1882869,
#    'tags': {'amenity': 'fast_food',
#     'brand': "McDonald's",
#     'brand:wikidata': 'Q38076',
#     'brand:wikipedia': "en:McDonald's",
#     'cuisine': 'burger',
#     'name': "McDonald's",
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 853942951,
#    'lat': 34.0990787,
#    'lon': -118.326905,
#    'tags': {'amenity': 'restaurant', 'name': "Tom Breneman's Restaurant"}},
#   {'type': 'node',
#    'id': 853984748,
#    'lat': 34.046284,
#    'lon': -118.249232,
#    'tags': {'amenity': 'restaurant', 'name': 'Majestic Malt Shop'}},
#   {'type': 'node',
#    'id': 902322506,
#    'lat': 34.1013804,
#    'lon': -118.293002,
#    'tags': {'amenity': 'fast_food', 'name': 'H.Salt Fish and Chips'}},
#   {'type': 'node',
#    'id': 902322507,
#    'lat': 34.1102782,
#    'lon': -118.287287,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'name': "Cheech's Pizza",
#     'opening_hours': 'Su-Th 11:00-22:00; Fr-Sa 11:00-23:00',
#     'phone': '+1-323-666-7744',
#     'website': 'cheechspizza.com'}},
#   {'type': 'node',
#    'id': 902322514,
#    'lat': 34.1116128,
#    'lon': -118.287845,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '4500',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'Los Feliz Boulevard',
#     'amenity': 'restaurant',
#     'cuisine': 'american;drinks;bbq',
#     'name': 'Messhall Kitchen',
#     'opening_hours': 'Su-Th 09:00-22:00; Fr-Sa 09:00-23:00',
#     'phone': '+1-323-660-6377',
#     'website': 'https://www.messhallkitchen.com/'}},
#   {'type': 'node',
#    'id': 902322516,
#    'lat': 34.1106298,
#    'lon': -118.28766,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '2121',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'Hillhurst Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'mexican',
#     'disused:amenity': '*',
#     'name': 'Mexico City',
#     'opening_hours': 'Mo-Th 17:00-22:00; Fr 12:00-15:00; Sa 17:00-23:00; Su 12:00-22:00'}},
#   {'type': 'node',
#    'id': 902322517,
#    'lat': 34.1026007,
#    'lon': -118.2920843,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '1727',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'North Vermont Avenue',
#     'addr:unit': '105',
#     'amenity': 'restaurant',
#     'cuisine': 'thai;asian',
#     'name': 'Pattaya Bai Thai Restaurant',
#     'opening_hours': 'Mo-Sa 11:00-02:00; Su 11:00-00:00',
#     'phone': '+1-323-666-0880',
#     'website': 'http://www.pattayabaythai.com/'}},
#   {'type': 'node',
#    'id': 902322522,
#    'lat': 34.10374,
#    'lon': -118.286982,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '1800',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'Hillhurst Avenue',
#     'amenity': 'bar',
#     'name': 'Drawing Room',
#     'opening_hours': 'Mo-Su 06:00-02:00',
#     'phone': '+1-323-665-0135'}},
#   {'type': 'node',
#    'id': 902322524,
#    'lat': 34.1046906,
#    'lon': -118.2872591,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '1850',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'Hillhurst Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'asian;thai',
#     'name': 'Simply Thai',
#     'opening_hours': 'Tu-Th 12:00-15:00,17:00-21:45; Fr 11:00-22:45; Sa 17:00-22:45; Su 17:00-22:00',
#     'phone': '+1-323-665-6958',
#     'start_date': '2000-08-25',
#     'website': 'https://simplythailosfeliz.net/'}},
#   {'type': 'node',
#    'id': 902322525,
#    'lat': 34.1040977,
#    'lon': -118.2877982,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '1813',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'Russell Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'chinese;asian',
#     'name': 'Chi Dynasty',
#     'opening_hours': 'Mo-Fr 06:00-21:00; Sa-Su 06:00-22:00',
#     'phone': '+1-323-667-3388',
#     'website': 'http://chidynasty.com/'}},
#   {'type': 'node',
#    'id': 902322526,
#    'lat': 34.1044069,
#    'lon': -118.2916172,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '1824',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'North Vermont Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'tacos',
#     'name': 'Tacos Tu Madre',
#     'opening_hours': 'Mo-Th 11:00-00:00; Fr-Su 10:00-00:00',
#     'phone': '+1-323-522-3651',
#     'takeaway': 'yes',
#     'website': 'http://tacostumadre.com/'}},
#   {'type': 'node',
#    'id': 902322527,
#    'lat': 34.1057345,
#    'lon': -118.287845,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'chinese'}},
#   {'type': 'node',
#    'id': 902322530,
#    'lat': 34.1062341,
#    'lon': -118.2877096,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '1929',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'Hillhurst Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'american;coffee;bakery;drinks',
#     'name': 'Alcove Cafe & Bakery',
#     'opening_hours': 'Mo-We 06:00-00:00; Th-Sa 06:00-01:00; Su 06:00-00:00',
#     'phone': '+1-323-644-0100',
#     'website': 'www.alcovecafe.com'}},
#   {'type': 'node',
#    'id': 902322531,
#    'lat': 34.1038999,
#    'lon': -118.2872188,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '1806 1/2',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'Hillhurst Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'thai;noodles',
#     'name': 'Tub Tim Siam',
#     'opening_hours': 'Mo-Su 11:00-22:45',
#     'phone': '+1-323-663-0050',
#     'website': 'tubtimsiamla.com'}},
#   {'type': 'node',
#    'id': 902322533,
#    'lat': 34.1055989,
#    'lon': -118.286962,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '1900',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'Hillhurst Avenue',
#     'amenity': 'fast_food',
#     'brand': 'Subway',
#     'brand:wikidata': 'Q244457',
#     'brand:wikipedia': 'en:Subway (restaurant)',
#     'cuisine': 'sandwich',
#     'name': 'Subway',
#     'phone': '+1 323 664 7827',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 902322534,
#    'lat': 34.105737,
#    'lon': -118.287023,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '1904 1/2',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'Hillhurst Avenue',
#     'amenity': 'fast_food',
#     'name': "Hot Chicko's",
#     'phone': '+1 323 522 6227'}},
#   {'type': 'node',
#    'id': 902322535,
#    'lat': 34.1057366,
#    'lon': -118.287138,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '1906',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'Hillhurst Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'vietnamese',
#     'name': 'Pho VT',
#     'phone': '+1 323 486 7767'}},
#   {'type': 'node',
#    'id': 902322536,
#    'lat': 34.1098325,
#    'lon': -118.287797,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '2081',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'Hillhurst Avenue',
#     'amenity': 'cafe',
#     'brand': 'The Coffee Bean & Tea Leaf',
#     'brand:wikidata': 'Q1141384',
#     'brand:wikipedia': 'en:The Coffee Bean & Tea Leaf',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'yes',
#     'name': 'The Coffee Bean & Tea Leaf',
#     'opening_hours': 'Mo-Th 05:30-23:00; Fr 05:30-24:00; Sa 06:00-24:00; Su 06:00-23:00',
#     'phone': '+1-323-913-3457',
#     'takeaway': 'yes',
#     'website': 'https://www.coffeebean.com/'}},
#   {'type': 'node',
#    'id': 902322537,
#    'lat': 34.1032292,
#    'lon': -118.2919463,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:housenumber': '1767',
#     'addr:postcode': '90027',
#     'addr:state': 'CA',
#     'addr:street': 'North Vermont Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'armenian',
#     'name': 'Monte Cristo',
#     'note': 'Banquet Hall',
# ...
#     'addr:postcode': '91303',
#     'addr:state': 'CA',
#     'addr:street': 'Sherman Way',
#     'amenity': 'cafe',
#     'coffee': 'yes',
#     'contact:email': 'cbesancon@followyourheart.com',
#     'contact:facebook': 'https://www.facebook.com/FollowYourHeartMarketCafe',
#     'contact:instagram': 'https://www.instagram.com/followyourheart',
#     'description': 'Oldest vegetarian restaurant in the United States.',
#     'diet:lacto_vegetarian': 'only',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'only',
#     'name': 'Follow Your Heart Cafe',
#     'opening_hours': '08:00-21:00',
#     'organic': 'yes',
#     'shop': 'grocery',
#     'website': 'https://followyourheart.com/follow-your-heart-market-and-cafe/'}},
#   {'type': 'node',
#    'id': 3840429398,
#    'lat': 34.2012132,
#    'lon': -118.6065469,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'India Sweets & Spices'}},
#   {'type': 'node',
#    'id': 3840429399,
#    'lat': 34.2011872,
#    'lon': -118.6074743,
#    'tags': {'amenity': 'pub', 'music': 'live', 'name': 'Scotland Yard'}},
#   {'type': 'node',
#    'id': 3840429400,
#    'lat': 34.2012063,
#    'lon': -118.6070736,
#    'tags': {'amenity': 'bar', 'music': 'jazz', 'name': 'Caseys'}},
#   {'type': 'node',
#    'id': 3840429401,
#    'lat': 34.2012038,
#    'lon': -118.6075764,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'deli', 'name': 'Cavarettis'}},
#   {'type': 'node',
#    'id': 3840429402,
#    'lat': 34.2011996,
#    'lon': -118.6077087,
#    'tags': {'amenity': 'cafe', 'music': 'live', 'name': 'Cobalt Cafe'}},
#   {'type': 'node',
#    'id': 3841408091,
#    'lat': 34.2018579,
#    'lon': -118.6130172,
#    'tags': {'amenity': 'restaurant', 'name': "Weiler's Deli"}},
#   {'type': 'node',
#    'id': 3841408097,
#    'lat': 34.2022179,
#    'lon': -118.61301,
#    'tags': {'amenity': 'restaurant'}},
#   {'type': 'node',
#    'id': 3841408098,
#    'lat': 34.2022368,
#    'lon': -118.6123931,
#    'tags': {'amenity': 'restaurant'}},
#   {'type': 'node',
#    'id': 3844031633,
#    'lat': 34.1636592,
#    'lon': -118.5229926,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'sushi', 'name': 'Makato'}},
#   {'type': 'node',
#    'id': 3844031634,
#    'lat': 34.1637998,
#    'lon': -118.5232509,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'sandwich',
#     'diet:kosher': 'yes',
#     'name': 'Sandwich Bar 26'}},
#   {'type': 'node',
#    'id': 3844031635,
#    'lat': 34.1642074,
#    'lon': -118.5243713,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'diet:gluten_free': 'yes',
#     'name': 'Pizza Cookery'}},
#   {'type': 'node',
#    'id': 3844031636,
#    'lat': 34.1641673,
#    'lon': -118.5242381,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'mediterranean',
#     'name': 'Nara'}},
#   {'type': 'node',
#    'id': 3844031637,
#    'lat': 34.1652164,
#    'lon': -118.5258951,
#    'tags': {'amenity': 'restaurant', 'name': 'Aroma', 'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 3844031639,
#    'lat': 34.1638377,
#    'lon': -118.5233408,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'diet:gluten_free': 'yes',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'name': 'Carolina Cafe',
#     'organic': 'yes'}},
#   {'type': 'node',
#    'id': 3844031640,
#    'lat': 34.1643818,
#    'lon': -118.5248561,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'mediterranean',
#     'name': 'Shisha'}},
#   {'type': 'node',
#    'id': 3844031641,
#    'lat': 34.1648146,
#    'lon': -118.5259418,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'spanish', 'name': 'Vino'}},
#   {'type': 'node',
#    'id': 3847799464,
#    'lat': 34.1784706,
#    'lon': -118.6040452,
#    'tags': {'amenity': 'restaurant', 'name': 'Breeze'}},
#   {'type': 'node',
#    'id': 3847799465,
#    'lat': 34.1785384,
#    'lon': -118.603861,
#    'tags': {'amenity': 'bar', 'name': 'Q Bar'}},
#   {'type': 'node',
#    'id': 3847799466,
#    'lat': 34.1676478,
#    'lon': -118.5929861,
#    'tags': {'amenity': 'restaurant', 'name': 'Bistro'}},
#   {'type': 'node',
#    'id': 3847799476,
#    'lat': 34.2025269,
#    'lon': -118.5973396,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'barbecue',
#     'name': 'Champs Hot Grill'}},
#   {'type': 'node',
#    'id': 3847799477,
#    'lat': 34.2023697,
#    'lon': -118.5973461,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'asian', 'name': 'Oi'}},
#   {'type': 'node',
#    'id': 3847799478,
#    'lat': 34.2021938,
#    'lon': -118.5973534,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'indian', 'name': 'B3'}},
#   {'type': 'node',
#    'id': 3847799479,
#    'lat': 34.202281,
#    'lon': -118.5973497,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'chilean',
#     'name': 'Chilenazo'}},
#   {'type': 'node',
#    'id': 3847799482,
#    'lat': 34.1726977,
#    'lon': -118.5469889,
#    'tags': {'amenity': 'cafe',
#     'brand': "Peet's Coffee",
#     'brand:wikidata': 'Q1094101',
#     'brand:wikipedia': "en:Peet's Coffee",
#     'cuisine': 'coffee_shop',
#     'name': "Peet's Coffee",
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 3847799483,
#    'lat': 34.1721137,
#    'lon': -118.547582,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'sushi'}},
#   {'type': 'node',
#    'id': 3847799484,
#    'lat': 34.1720734,
#    'lon': -118.5454516,
#    'tags': {'amenity': 'restaurant', 'name': "Cici's"}},
#   {'type': 'node',
#    'id': 3848048136,
#    'lat': 34.1839073,
#    'lon': -118.5702627,
#    'tags': {'amenity': 'restaurant', 'name': 'WVOC Westside Cafe'}},
#   {'type': 'node',
#    'id': 3849945968,
#    'lat': 34.0836588,
#    'lon': -118.3447753,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:country': 'US',
#     'addr:housenumber': '7111',
#     'addr:postcode': '90046',
#     'addr:state': 'CA',
#     'addr:street': 'Melrose Avenue',
#     'amenity': 'fast_food',
#     'cuisine': 'sandwich',
#     'name': 'All about the Bread',
#     'opening_hours': 'Mo-Su 11:00-21:00',
#     'website': 'http://www.allaboutthebread.com/'}},
#   {'type': 'node',
#    'id': 3849945969,
#    'lat': 34.0835661,
#    'lon': -118.343264,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:country': 'US',
#     'addr:housenumber': '7013',
#     'addr:postcode': '90046',
#     'addr:state': 'CA',
#     'addr:street': 'Melrose Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'Anarkali',
#     'website': 'https://www.anarkaliindianrestaurant.com'}},
#   {'type': 'node',
#    'id': 3849945970,
#    'lat': 34.0834993,
#    'lon': -118.3527982,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:country': 'US',
#     'addr:housenumber': '7470',
#     'addr:postcode': '90046',
#     'addr:state': 'CA',
#     'addr:street': 'Melrose Avenue',
#     'amenity': 'restaurant',
#     'contact:phone': '+1 323 658 9060',
#     'cuisine': 'mexican',
#     'name': "Antonio's",
#     'opening_hours': 'Tu-Fr 11:00-23:00; Sa 12:00-23:00; Su 12:00-22:00'}},
#   {'type': 'node',
#    'id': 3849945972,
#    'lat': 34.0833373,
#    'lon': -118.3457966,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:country': 'US',
#     'addr:housenumber': '7168',
#     'addr:postcode': '90046',
#     'addr:state': 'CA',
#     'addr:street': 'Melrose Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'thai',
#     'name': 'Ruam Mitr',
#     'phone': '+1 (323) 857-1882',
#     'website': 'http://www.bulanthai.com'}},
#   {'type': 'node',
#    'id': 3849945976,
#    'lat': 34.0835725,
#    'lon': -118.343201,
#    'tags': {'amenity': 'cafe', 'name': 'Hot Wings'}},
#   {'type': 'node',
#    'id': 3849945986,
#    'lat': 34.0835645,
#    'lon': -118.3433317,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:country': 'US',
#     'addr:housenumber': '7015',
#     'addr:postcode': '90046',
#     'addr:state': 'CA',
#     'addr:street': 'Melrose Avenue',
#     'amenity': 'restaurant',
#     'cuisine': 'sushi',
#     'name': 'Tsuri',
#     'website': 'http://www.tsurila.com/'}},
#   {'type': 'node',
#    'id': 3852390072,
#    'lat': 34.1013737,
#    'lon': -118.3428689,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'pizza',
#     'name': "Andre's Pizza"}},
#   {'type': 'node',
#    'id': 3852390073,
#    'lat': 34.1013019,
#    'lon': -118.3435808,
#    'tags': {'addr:state': 'CA',
#     'amenity': 'restaurant',
#     'brand': 'Buffalo Wild Wings',
#     'brand:wikidata': 'Q509255',
#     'brand:wikipedia': 'en:Buffalo Wild Wings',
#     'cuisine': 'wings',
#     'name': 'Buffalo Wild Wings',
#     'website': 'https://www.buffalowildwings.com/'}},
#   {'type': 'node',
#    'id': 3855955433,
#    'lat': 33.9905293,
#    'lon': -118.4650497,
#    'tags': {'amenity': 'fast_food', 'name': 'GTA (Gjelina Take Away)'}},
#   {'type': 'node',
#    'id': 3855955434,
#    'lat': 33.9905045,
#    'lon': -118.4649582,
#    'tags': {'amenity': 'restaurant', 'name': 'Gjelina'}},
#   {'type': 'node',
#    'id': 3855965601,
#    'lat': 33.991026,
#    'lon': -118.4669414,
#    'tags': {'addr:city': 'Venice',
#     'addr:housenumber': '1331',
#     'addr:postcode': '90291',
#     'addr:state': 'CA',
#     'addr:street': 'Abbot Kinney Boulevard',
#     'amenity': 'cafe',
#     'name': 'Intelligentsia Coffee',
#     'name:zh': 'Intelligentsia咖啡',
#     'phone': '+1 310 399 1233',
#     'website': 'http://www.intelligentsiacoffee.com/location/venice-coffeebar'}},
#   {'type': 'node',
#    'id': 3861449033,
#    'lat': 34.101755,
#    'lon': -118.3358181,
#    'tags': {'amenity': 'pub', 'name': "Jameson's Irish Pub"}},
#   {'type': 'node',
#    'id': 3861449034,
#    'lat': 34.1013926,
#    'lon': -118.3364747,
#    'tags': {'amenity': 'bar',
#     'name': 'Juicy Factory',
#     'website': 'http://www.juicyfactory.com/'}},
#   {'type': 'node',
#    'id': 3861449035,
#    'lat': 34.1017261,
#    'lon': -118.3371834,
#    'tags': {'amenity': 'fast_food', 'name': 'Juicy'}},
#   {'type': 'node',
#    'id': 3861449036,
#    'lat': 34.10172,
#    'lon': -118.3367106,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:country': 'US',
#     'addr:housenumber': '6721',
#     'addr:postcode': '90028',
#     'addr:state': 'CA',
#     'addr:street': 'Hollywood Boulevard',
#     'amenity': 'restaurant',
#     'cuisine': 'sushi',
#     'name': 'Kino Sushi'}},
#   {'type': 'node',
#    'id': 3861449037,
#    'lat': 34.101764,
#    'lon': -118.3359275,
#    'tags': {'addr:city': 'Los Angeles',
#     'addr:country': 'US',
#     'addr:housenumber': '1708',
#     'addr:postcode': '90028',
#     'addr:state': 'CA',
#     'addr:street': 'North Las Palmas Avenue',
#     'amenity': 'restaurant',
#     'name': 'Rusty Mullet'}},
#   {'type': 'node',
#    'id': 3861449040,
#    'lat': 34.1017368,
#    'lon': -118.3364228,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'italian',
#     'name': "Stefano's - Two Guys from Italy"}},
#   {'type': 'node',
#    'id': 3866227486,
#    'lat': 34.1839341,
#    'lon': -118.6048298,
#    'tags': {'amenity': 'restaurant',
#     'beer': 'yes',
#     'dog': 'leashed;clean;friendly',
#     'name': 'Slawdogs',
#     'outdoor_counter': 'yes',
#     'outdoor_seating': 'yes',
#     'wine': 'yes'}},
#   {'type': 'node',
#    'id': 3869786465,
#    'lat': 34.1013892,
#    'lon': -118.339236,
#    'tags': {'amenity': 'fast_food',
#     'cuisine': 'pizza',
#     'name': 'Grecos New York Pizzeria'}},
#   {'type': 'node',
#    'id': 3870409262,
#    'lat': 34.1784502,
#    'lon': -118.6028249,
#    'tags': {'amenity': 'restaurant', 'name': 'Cafe Valentino'}},
#   {'type': 'node',
#    'id': 3878770862,
#    'lat': 34.0976026,
#    'lon': -118.3431895,
#    'tags': {'amenity': 'fast_food',
#     'cuisine': 'chinese',
#     'name': 'Ohana Hawaiian BBQ'}},
#   {'type': 'node',
#    'id': 3878792658,
#    'lat': 34.0985106,
#    'lon': -118.3438446,
#    'tags': {'addr:city': 'Hollywood',
#     'addr:housenumber': '7075',
#     'addr:postcode': '90028',
#     'addr:street': 'West Sunset Boulevard',
#     'amenity': 'restaurant',
#     'cuisine': 'thai',
#     'description': 'Thai-Sunset-La Brea',
#     'name': 'Pa Ord Noodle',
#     'opening_hours': '11:00-22:45',
#     'phone': '(323) 464-2989',
#     'website': 'http://www.paordnoodle.com'}},
#   {'type': 'node',
#    'id': 3880792929,
#    'lat': 33.9614866,
#    'lon': -118.4455849,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'chinese',
#     'name': 'Szechuan Palace'}},
#   {'type': 'node',
#    'id': 3884275117,
#    'lat': 34.0434456,
#    'lon': -118.3041726,
#    'tags': {'amenity': 'fast_food',
#     'name': 'Tacos Locos',
#     'opening_hours': 'Mo-Su 08:30-22:00'}},
#   {'type': 'node',
#    'id': 3887073511,
#    'lat': 34.1656853,
#    'lon': -118.62298,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'thai',
#     'name': 'Exotic Thai'}},
#   {'type': 'node',
#    'id': 3887073512,
#    'lat': 34.1651856,
#    'lon': -118.6266218,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'mexican', 'name': "Hugo's"}},
#   {'type': 'node',
#    'id': 3887073513,
#    'lat': 34.1649256,
#    'lon': -118.6272935,
#    'tags': {'addr:city': 'Woodland Hills',
#     'addr:housenumber': '23011',
#     'addr:postcode': '91364',
#     'addr:state': 'CA',
#     'addr:street': 'Ventura Blvd',
#     'amenity': 'restaurant',
#     'cuisine': 'indian',
#     'name': 'Shalimar',
#     'phone': '+1-818-225-7794',
#     'website': 'http://shalimarindian.com'}},
#   {'type': 'node',
#    'id': 3887073531,
#    'lat': 34.1654012,
#    'lon': -118.626004,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'chinese'}},
#   {'type': 'node',
#    'id': 3887073532,
#    'lat': 34.165805,
#    'lon': -118.6247734,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'italian', 'name': 'Adagio'}},
#   {'type': 'node',
#    'id': 3887073533,
#    'lat': 34.165943,
#    'lon': -118.6241093,
#    'tags': {'amenity': 'restaurant',
#     'cuisine': 'coffee_shop',
#     'name': "Bobby's"}},
#   {'type': 'node',
#    'id': 3887073534,
#    'lat': 34.1644704,
#    'lon': -118.6266762,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'pizza', 'name': 'Topanga'}},
#   {'type': 'node',
#    'id': 3887073535,
#    'lat': 34.1646051,
#    'lon': -118.6264356,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'thai', 'name': 'Red Ginger'}},
#   {'type': 'node',
#    'id': 3887073541,
#    'lat': 34.1666665,
#    'lon': -118.6203065,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Jack in the Box',
#     'brand:wikidata': 'Q1538507',
#     'brand:wikipedia': 'en:Jack in the Box',
#     'cuisine': 'burger',
#     'name': 'Jack in the Box',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 3887073543,
#    'lat': 34.1670099,
#    'lon': -118.6191988,
#    'tags': {'amenity': 'restaurant', 'name': 'Lukes'}},
#   {'type': 'node',
#    'id': 3887073549,
#    'lat': 34.1685842,
#    'lon': -118.616019,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'pizza', 'name': "Barone's"}},
#   {'type': 'node',
#    'id': 3887073554,
#    'lat': 34.1746485,
#    'lon': -118.5969428,
#    'tags': {'amenity': 'fast_food',
#     'brand': 'Baja Fresh',
#     'brand:wikidata': 'Q2880019',
#     'brand:wikipedia': 'en:Baja Fresh',
#     'cuisine': 'mexican',
#     'name': 'Baja Fresh',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 3887073555,
#    'lat': 34.1750579,
#    'lon': -118.5968955,
#    'tags': {'amenity': 'cafe', 'name': 'Coffee Bean'}},
#   {'type': 'node',
#    'id': 3887073556,
#    'lat': 34.1749465,
#    'lon': -118.5969773,
#    'tags': {'amenity': 'restaurant', 'name': 'The Stand'}},
#   {'type': 'node',
#    'id': 3887073957,
#    'lat': 34.1747403,
#    'lon': -118.5969755,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'greek', 'name': "Daphne's"}},
#   {'type': 'node',
#    'id': 3887073958,
#    'lat': 34.1748457,
#    'lon': -118.5969773,
#    'tags': {'amenity': 'restaurant', 'name': 'Salad Farm'}},
#   {'type': 'node',
#    'id': 3887251654,
#    'lat': 34.1793623,
#    'lon': -118.6238032,
#    'tags': {'amenity': 'restaurant', 'name': 'Alborz'}},
#   {'type': 'node',
#    'id': 3887285976,
#    'lat': 34.1888193,
#    'lon': -118.5968258,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'burger', 'name': 'Topz'}},
#   {'type': 'node',
#    'id': 3888036880,
#    'lat': 34.187587,
#    'lon': -118.5979508,
#    'tags': {'amenity': 'restaurant', 'cuisine': 'pizza', 'name': 'Pizza Rev'}},
#   {'type': 'node',
#    'id': 3890744009,
#    'lat': 34.1875005,
#    'lon': -118.5979337,
#    'tags': {'amenity': 'restaurant', 'name': 'Gaucho Grill'}},
#   {'type': 'node',
#    'id': 3890744010,
#    'lat': 34.1877681,
#    'lon': -118.5993073,
#    'tags': {'amenity': 'fast_food',
#     'brand': "Togo's",
#     'brand:wikidata': 'Q3530375',
#     'brand:wikipedia': "en:Togo's",
#     'cuisine': 'sandwich',
#     'name': "Togo's",
#     'takeaway': 'yes'}},
#   ...]}

# %%
sustenance_df = pd.DataFrame(sustenance_data["elements"])
sustenance_df.head(2)
# Out:
#    type        id        lat         lon  \
# 0  node  72448982  34.076217 -118.216020
# 1  node  72448995  34.076693 -118.216013
#
#                                                 tags
# 0  {'amenity': 'fast_food', 'cuisine': 'japanese'...
# 1  {'amenity': 'fast_food', 'cuisine': 'burger', ...

# %%
sustenance_df['category'] = 'sustenance'
sustenance_df['amenity'] = sustenance_df['tags'].apply(lambda tags: tags['amenity'])
sustenance_df.head()
# Out:
#    type         id        lat         lon  \
# 0  node   72448982  34.076217 -118.216020
# 1  node   72448995  34.076693 -118.216013
# 2  node   77741928  34.190943 -118.330511
# 3  node  344723703  34.185572 -118.316496
# 4  node  344723888  34.185624 -118.316329
#
#                                                 tags    category     amenity
# 0  {'amenity': 'fast_food', 'cuisine': 'japanese'...  sustenance   fast_food
# 1  {'amenity': 'fast_food', 'cuisine': 'burger', ...  sustenance   fast_food
# 2  {'amenity': 'restaurant', 'cuisine': 'american...  sustenance  restaurant
# 3  {'amenity': 'fast_food', 'brand': 'Baja Fresh'...  sustenance   fast_food
# 4  {'amenity': 'fast_food', 'brand': 'Jersey Mike...  sustenance   fast_food

# %%
overpass_query = """
    [out:json]; 
    area[name = "Los Angeles"]->.a; 
    (   
      node(area.a)[highway=bus_stop];
      node(area.b)[highway=bus_stop];
      node(area.c)[highway=bus_stop];
    ); 
    out; 
"""
response = requests.get(overpass_url, params={"data": overpass_query})
bus_data = response.json()

# %%
bus_df = pd.DataFrame(bus_data["elements"])
bus_df.head(2)
# Out:
#    type         id        lat         lon  \
# 0  node  349443839  34.079103 -118.291534
# 1  node  368062538  34.054432 -118.237308
#
#                                                 tags
# 0  {'bus': 'yes', 'highway': 'bus_stop', 'public_...
# 1  {'bus': 'yes', 'highway': 'bus_stop', 'name': ...

# %%
bus_df['category'] = 'public transport'
bus_df['amenity'] = 'bus stop'
bus_df.head(2)
# Out:
#    type         id        lat         lon  \
# 0  node  349443839  34.079103 -118.291534
# 1  node  368062538  34.054432 -118.237308
#
#                                                 tags          category  \
# 0  {'bus': 'yes', 'highway': 'bus_stop', 'public_...  public transport
# 1  {'bus': 'yes', 'highway': 'bus_stop', 'name': ...  public transport
#
#     amenity
# 0  bus stop
# 1  bus stop

# %%
overpass_query = """
    [out:json]; 
    area[name = "Los Angeles"]->.a; 
    (   
      node(area.a)[railway=station];
      node(area.b)[railway=station];
      node(area.c)[railway=station];
    ); 
    out; 
"""
response = requests.get(overpass_url, params={"data": overpass_query})
railway_data = response.json()

# %%
railway_df = pd.DataFrame(railway_data["elements"])
railway_df.head(2)
# Out:
#    type         id        lat         lon  \
# 0  node  123386730  34.026363 -118.372152
# 1  node  267072333  34.087521 -118.475692
#
#                                                 tags
# 0  {'addr:city': 'Los Angeles', 'addr:housenumber...
# 1  {'name': 'Lower Tram Station', 'railway': 'sta...

# %%
railway_df['category'] = 'public transport'
railway_df['amenity'] = 'railway stop'
railway_df.head(2)
# Out:
#    type         id        lat         lon  \
# 0  node  123386730  34.026363 -118.372152
# 1  node  267072333  34.087521 -118.475692
#
#                                                 tags          category  \
# 0  {'addr:city': 'Los Angeles', 'addr:housenumber...  public transport
# 1  {'name': 'Lower Tram Station', 'railway': 'sta...  public transport
#
#         amenity
# 0  railway stop
# 1  railway stop

# %%
pois_df = pd.concat([sustenance_df, bus_df, railway_df])

# %%
pois_df['hex'] = pois_df.apply(lambda poi: convert_to_hex(poi['lat'], poi['lon'], 8), axis=1)
pois_df.head(2)
# Out:
#    type        id        lat         lon  \
# 0  node  72448982  34.076217 -118.216020
# 1  node  72448995  34.076693 -118.216013
#
#                                                 tags    category    amenity  \
# 0  {'amenity': 'fast_food', 'cuisine': 'japanese'...  sustenance  fast_food
# 1  {'amenity': 'fast_food', 'cuisine': 'burger', ...  sustenance  fast_food
#
#                hex
# 0  8829a1d73dfffff
# 1  8829a1d73dfffff

# %%
pois_df[pois_df['amenity'] == 'bus stop'].head(2)
# Out:
#    type         id        lat         lon  \
# 0  node  349443839  34.079103 -118.291534
# 1  node  368062538  34.054432 -118.237308
#
#                                                 tags          category  \
# 0  {'bus': 'yes', 'highway': 'bus_stop', 'public_...  public transport
# 1  {'bus': 'yes', 'highway': 'bus_stop', 'name': ...  public transport
#
#     amenity              hex
# 0  bus stop  8829a1d459fffff
# 1  bus stop  8829a1d757fffff

# %%
pois_df[pois_df['amenity'] == 'railway stop'].head(2)
# Out:
#    type         id        lat         lon  \
# 0  node  123386730  34.026363 -118.372152
# 1  node  267072333  34.087521 -118.475692
#
#                                                 tags          category  \
# 0  {'addr:city': 'Los Angeles', 'addr:housenumber...  public transport
# 1  {'name': 'Lower Tram Station', 'railway': 'sta...  public transport
#
#         amenity              hex
# 0  railway stop  8829a1990bfffff
# 1  railway stop  8829a198b5fffff

# %%
all_hexagons_with_pois = pois_df.groupby(['hex', 'category']).size().to_frame()
all_hexagons_with_pois = all_hexagons_with_pois.reset_index()
all_hexagons_with_pois = all_hexagons_with_pois.rename(columns={0: 'number of pois'})
all_hexagons_with_pois.head(2)
# Out:
#                hex    category  number of pois
# 0  881f9c344dfffff  sustenance               1
# 1  882664501bfffff  sustenance               1

# %%
hexagons_df["hex_and_neighbors"] = hexagons_df.apply(
    lambda row: list(h3.k_ring(row["hex"], 1)), axis=1
)
hexagons_df.head(2)
# Out:
#                hex                                  hex_and_neighbors
# 0  8829a1d757fffff  [8829a1d755fffff, 8829a1d753fffff, 8829a1d719f...
# 1  8829a1d755fffff  [8829a1d755fffff, 8829a1d709fffff, 8829a1d757f...

# %%
hexagons_df['hex_and_neighbors'][0]
# Out:
# ['8829a1d755fffff',
#  '8829a1d753fffff',
#  '8829a1d719fffff',
#  '8829a1d757fffff',
#  '8829a1d71dfffff',
#  '8829a1d751fffff',
#  '8829a1d70bfffff']

# %%
def calculate_pois(hex_and_neighbors, category):
    return all_hexagons_with_pois[
        ((all_hexagons_with_pois["hex"].isin(hex_and_neighbors))
        & (all_hexagons_with_pois["category"] == category))
    ]["number of pois"].sum()

# %%
hexagons_df['sustenance_pois'] = hexagons_df["hex_and_neighbors"].apply(lambda row: calculate_pois(row, 'sustenance'))
hexagons_df['public_transport_pois'] = hexagons_df["hex_and_neighbors"].apply(lambda row: calculate_pois(row, 'public transport'))
hexagons_df.head(2)
# Out:
#                hex                                  hex_and_neighbors  \
# 0  8829a1d757fffff  [8829a1d755fffff, 8829a1d753fffff, 8829a1d719f...
# 1  8829a1d755fffff  [8829a1d755fffff, 8829a1d709fffff, 8829a1d757f...
#
#    sustenance_pois  public_transport_pois
# 0              250                    133
# 1              115                     54

# %%
pois_df.to_pickle('../00_data/pois.pkl')
hexagons_df.to_pickle('../00_data/hexagons.pkl')
trips_df.to_pickle('../00_data/trips.pkl')
